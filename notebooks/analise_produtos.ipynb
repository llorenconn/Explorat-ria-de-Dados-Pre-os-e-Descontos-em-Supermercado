# %%
from src.carregar_dados import carregar_dados
from src.limpeza import limpar_dados
from src.graficos import grafico_categoria, grafico_top10, grafico_descontos
from src.analise import insights

# 1. carregar dados
df = carregar_dados("../data/produtos.csv")

# 2. limpar dados
df = limpar_dados(df)

# 3. gráficos
grafico_categoria(df)
grafico_top10(df)
grafico_descontos(df)

# 4. insights
insights(df)
